# %%
import pandas as pd
from sqlalchemy import create_engine
# pd.set_option('display.max_rows', None) 
# df = pd.read_csv("/home/julien/Downloads/tgvmax.csv", sep=";")
# engine = create_engine('sqlite:///:memory:')
# df.rename(columns={"Disponibilité de places MAX JEUNE et MAX SENIOR":"DISPO"}, inplace=True)
# df.to_sql('TGVMAX', con=engine, index=False, if_exists='replace')
# df.head()
# Out:
#          DATE  TRAIN_NO      ENTITY      Axe Origine IATA Destination IATA  \
# 0  2024-10-17      6627  PARISRHONE  SUD EST        FRPLY            FRXCC
# 1  2024-10-21      4402  JOURNTELYN   IC SRO        FRBOU            FRLPE
# 2  2024-10-18      6871   JCSUDPROV  SUD EST        FRXYT            FRXSY
# 3  2024-10-21      7385     PAARRAS     NORD        FRPNO            FRQRV
# 4  2024-11-08      9402  MULHSTRAPA      EST        DEZPA            FREAH
#
#                 Origine                     Destination Heure_depart  \
# 0    PARIS (intramuros)  LE CREUSOT MONTCEAU MONTCHANIN        17:52
# 1               BOURGES               LYON (intramuros)        09:40
# 2     TOULOUSE MATABIAU                            SETE        07:39
# 3    PARIS (intramuros)                           ARRAS        18:49
# 4  OFFENBOURG/OFFENBURG               CHAMPAGNE-ARDENNE        17:41
#
#   Heure_arrivee DISPO
# 0         19:09   NON
# 1         13:22   NON
# 2         09:34   OUI
# 3         19:40   OUI
# 4         19:28   NON

# %%
query = """
SELECT aller.Destination, aller.Heure_depart, aller.Heure_arrivee, retour.Heure_depart as retour_heure_depart, retour.Heure_arrivee as retour_heure_arrivee, (24 - aller.Heure_arrivee + retour.Heure_depart) as temps_sur_place
FROM TGVMAX as aller
JOIN (SELECT *
      FROM TGVMAX 
      WHERE DATE = :date2 AND Destination = :ville AND DISPO = 'OUI' AND Axe != 'IC NUIT') as retour
ON aller.Destination = retour.Origine
WHERE aller.DATE = :date1 AND aller.DISPO = 'OUI' AND aller.Origine = :ville AND aller.Axe != 'IC NUIT'
ORDER BY (24 - aller.Heure_arrivee + retour.Heure_depart) DESC
"""

result_df = pd.read_sql(query, con=engine, params={'date1':'2024-10-19', 'date2':'2024-10-20', 'ville':'PARIS (intramuros)'})
result_df.head(1000)
# Out:
#                   Destination Heure_depart Heure_arrivee retour_heure_depart  \
# 0                       ARRAS        07:49         08:40               22:18
# 1                       ARRAS        07:49         08:40               22:18
# 2                       ARRAS        07:49         08:40               21:18
# 3                       ARRAS        07:49         08:40               21:18
# 4                       ARRAS        10:50         11:40               22:18
# 5                       ARRAS        10:50         11:40               22:18
# 6                       ARRAS        10:50         11:40               21:18
# 7                       ARRAS        10:50         11:40               21:18
# 8                       ARRAS        13:49         14:40               22:18
# 9                       ARRAS        13:49         14:40               22:18
# 10                      VICHY        07:01         09:53               17:06
# 11         MOULINS SUR ALLIER        07:01         09:25               17:32
# 12                      ARRAS        13:49         14:40               21:18
# 13                      ARRAS        13:49         14:40               21:18
# 13                22:14               31
# 14                23:09               30
# 15                23:09               30
# 16                22:14               29
# 17                22:14               29
# 18                16:57               29
# 19                16:57               29
# 20                23:09               28
# 21                23:09               28
# 22                22:14               27
# 23                22:14               27
# 24                23:09               26
# 25                23:09               26
# 26                23:09               26
# 27                23:09               26
# 28                22:14               25
# 29                22:14               25
# 30                22:14               25
# 31                22:14               25
# 32                10:11               25
# 33                10:11               24
# 34                23:09               24
# 35                23:09               24
# 36                22:14               23
# 37                22:14               23
# 38                10:11               23
# 39                10:11               22
# 40                10:11               19
# 41                10:11               17
# 42                09:31               16
# 43                13:30               16
# 44                13:30               16
# 45                13:30               16
# 46                10:11               15
# 47                09:31               15
# 48                10:11               14
# 49                10:11               13
# 50                10:11               13
# 51                10:11               13
# 52                09:31               12
# 53                09:31               12
# 54                09:31               11
# 55                09:31               11
# 56                10:11               11
# 57                09:31               10
# 58                09:31               10
# 59                09:31               10
# 60                09:31               10
# 61                09:31                9
# 62                09:31                9
# 63                09:31                8
# 64                09:31                6
# 65                09:31                5

# %%
query = """
SELECT aller.Destination, aller.Heure_depart, aller.Heure_arrivee, retour.Heure_depart as retour_heure_depart, retour.Heure_arrivee as retour_heure_arrivee, (retour.Heure_depart - aller.Heure_arrivee) as temps_sur_place
FROM TGVMAX as aller
JOIN (SELECT *
      FROM TGVMAX 
      WHERE DATE = :date2 AND Destination = :ville AND DISPO = 'OUI' AND Axe != 'IC NUIT') as retour
ON aller.Destination = retour.Origine
WHERE aller.DATE = :date1 AND aller.DISPO = 'OUI' AND aller.Origine = :ville AND aller.Axe != 'IC NUIT' AND temps_sur_place > 0
ORDER BY temps_sur_place DESC
"""

result_df = pd.read_sql(query, con=engine, params={'date1':'2024-10-19', 'date2':'2024-10-19', 'ville':'PARIS (intramuros)'})
result_df.head(1000)
# Out:
#                        Destination Heure_depart Heure_arrivee  \
# 0                            ARRAS        07:49         08:40
# 1                            ARRAS        07:49         08:40
# 2                            ARRAS        07:49         08:40
# 3                            ARRAS        07:49         08:40
# 4                          BETHUNE        07:49         09:15
# 5                            DOUAI        07:49         08:58
# 6                             LENS        07:49         09:02
# 7                       HAZEBROUCK        07:49         09:38
# 8                            VICHY        07:01         09:53
# 9               MOULINS SUR ALLIER        07:01         09:25
# 10                        POITIERS        07:24         09:34
# 11                   CHATELLERAULT        07:24         09:07
# 12                     FUTUROSCOPE        07:24         09:22
# 13                           ARRAS        07:49         08:40
# 14                           ARRAS        07:49         08:40
# 15                           ARRAS        10:50         11:40
# 16                           ARRAS        10:50         11:40
# 17                    VALENCIENNES        07:49         09:34
# 18                       DUNKERQUE        07:49         10:02
# 19                       DUNKERQUE        07:49         10:02
# 20                           ARRAS        10:50         11:40
# 21                           ARRAS        10:50         11:40
# 22                           ARRAS        07:49         08:40
# 23                           ARRAS        07:49         08:40
# 24                           VICHY        07:01         09:53
# 7                20:20                22:14               11
# 8                20:06                22:57               11
# 9                20:32                22:57               11
# 10               19:23                21:17               10
# 11               19:47                21:17               10
# 12               19:33                21:17               10
# 13               18:18                19:10               10
# 14               18:18                19:10               10
# 15               21:18                22:14               10
# 16               21:18                22:14               10
# 17               19:16                21:10               10
# 18               19:08                21:10                9
# 19               19:56                22:14                9
# 20               20:18                21:10                9
# 21               20:18                21:10                9
# 22               16:25                17:16                8
# 23               16:25                17:16                8
# 24               17:06                20:02                8
# 25               17:32                20:02                8
# 26               21:18                22:14                7
# 27               21:18                22:14                7
# 28               16:19                18:33                7
# 29               16:44                18:33                7
# 30               16:30                18:33                7
# 31               16:02                17:16                7
# 32               18:18                19:10                7
# 33               18:18                19:10                7
# 34               20:18                21:10                6
# 35               20:18                21:10                6
# 36               15:48                17:16                6
# 37               21:47                23:28                6
# 38               21:49                23:08                6
# 39               14:18                15:09                6
# 40               15:25                17:16                6
# 41               20:50                22:31                5
# 42               15:01                17:16                5
# 43               16:25                17:16                5
# 44               16:25                17:16                5
# 45               21:13                23:28                5
# 46               21:18                22:14                5
# 47               21:18                22:14                5
# 48               20:51                22:14                5
# 49               18:18                19:10                4
# 50               18:18                19:10                4
# 51               19:53                21:31                4
# 52               20:16                22:31                4
# 53               20:18                21:10                4
# 54               20:18                21:10                4
# 55               19:51                21:10                4
# 56               20:51                22:14                3
# 57               21:18                22:14                3
# 58               21:18                22:14                3
# 59               18:49                20:08                3
# 60               20:43                22:14                3
# 61               20:57                22:14                3
# 62               20:20                22:14                3
# 63               14:18                15:09                3
# 64               19:18                21:31                3
# 65               19:51                21:10                2
# 66               16:25                17:16                2
# 67               16:25                17:16                2
# 68               20:18                21:10                2
# 69               20:18                21:10                2
# 70               21:47                23:28                2
# 71               21:13                23:28                2
# 72               18:18                19:10                2
# 73               18:18                19:10                2
# 74               17:51                19:10                2
# 75               16:54                18:31                1
# 76               21:18                22:14                1
# 77               21:18                22:14                1
# 78               19:08                21:10                1
# 79               19:56                22:14                1
# 80               21:47                23:28                1
# 81               21:41                23:14                1
# 82               20:50                22:31                1
# 83               21:18                22:14                1
# 84               21:18                22:14                1
# 85               20:16                22:31                1
# 86               19:52                21:10                1
# 87               20:51                22:14                1

# %%
from sqlalchemy import create_engine
import pandas as pd

# Connect to a file-based SQLite database
engine = create_engine('sqlite:///tgvmax.db')  # Will create tgvmax.db in the working directory

# Load CSV and populate the database
df = pd.read_csv("/home/julien/Downloads/tgvmax.csv", sep=";")
df.rename(columns={"Disponibilité de places MAX JEUNE et MAX SENIOR":"DISPO"}, inplace=True)
df.to_sql('TGVMAX', con=engine, index=False, if_exists='replace')

# %%
import requests
import datetime


# Define the base URL for the API request
url = "https://ressources.data.sncf.com/api/explore/v2.1/catalog/datasets/tgvmax/records"

# Initialize variables
all_data = []  # List to store all records
limit = 100  # You can adjust this number as needed
offset = 0
params = {
    'limit': limit,  # Number of records to retrieve per request
    'offset': offset,  # Starting point
    'timezone': 'Europe/Berlin'
}

dates = [datetime.datetime.today()+datetime.timedelta(i) for i in range(60)]
dates = list(map(lambda date: date.strftime('%Y-%m-%d'), dates))
print(dates)
for date in dates:
    while True:
        # Update the offset in params
        params['offset'] = offset

        # Make the API request
        response = requests.get(url, params=params)

        # Check if the request was successful
        if response.status_code == 200:
            data = response.json()

            # Append the retrieved records to the all_data list
            all_data.extend(data['results'])

            # Increment the offset for the next batch
            offset += limit
            # break
        else:
            print(f"Failed to retrieve data. Status code: {response.status_code}")
            print(response.text)
            break

# Print the total number of records retrieved
print(f"Total records retrieved: {len(all_data)}")
# Out:
# ['2024-10-18', '2024-10-19', '2024-10-20', '2024-10-21', '2024-10-22', '2024-10-23', '2024-10-24', '2024-10-25', '2024-10-26', '2024-10-27', '2024-10-28', '2024-10-29', '2024-10-30', '2024-10-31', '2024-11-01', '2024-11-02', '2024-11-03', '2024-11-04', '2024-11-05', '2024-11-06', '2024-11-07', '2024-11-08', '2024-11-09', '2024-11-10', '2024-11-11', '2024-11-12', '2024-11-13', '2024-11-14', '2024-11-15', '2024-11-16', '2024-11-17', '2024-11-18', '2024-11-19', '2024-11-20', '2024-11-21', '2024-11-22', '2024-11-23', '2024-11-24', '2024-11-25', '2024-11-26', '2024-11-27', '2024-11-28', '2024-11-29', '2024-11-30', '2024-12-01', '2024-12-02', '2024-12-03', '2024-12-04', '2024-12-05', '2024-12-06', '2024-12-07', '2024-12-08', '2024-12-09', '2024-12-10', '2024-12-11', '2024-12-12', '2024-12-13', '2024-12-14', '2024-12-15', '2024-12-16']

# %%
import requests
import pandas as pd
import unicodedata

def clean_nom(nom):
    # Replace hyphens with spaces
    nom = nom.lower().replace(" - ", " ").replace("-", " ").replace("saint", "st").replace("sainte", "ste")
    # Normalize the string to decompose accents and diacritics
    nom = unicodedata.normalize('NFKD', nom)
    # Remove accents by filtering out non-ASCII characters
    nom = ''.join(c for c in nom if not unicodedata.combining(c))
    # Convert to lowercase
    return nom.lower()



df = pd.read_csv("data/gares-de-voyageurs.csv", sep=";")
df["Nom"] = list(map(clean_nom, df["Nom"]))
df = df.dropna(subset="Position géographique")

df["latitude"] = list(map(lambda x: x.split(', ')[0], df["Position géographique"]))
df["longitude"] = list(map(lambda x: x.split(', ')[1], df["Position géographique"]))


df = df[["Nom", "latitude", "longitude"]]
df.to_csv("gares_positions.csv")


def get_position(gare_name):
    gare_name = gare_name.lower().replace(" - ", " ").replace("-", " ").replace("saint", "st").replace("sainte", "ste")
    result = df[df["Nom"] == gare_name.lower()]
    if len(result) == 1:
        return result.iloc[0].values[1:]
    result = df[df["Nom"] == gare_name[:-6].lower()]
    if len(result) == 1:
        return result.iloc[0].values[1:]
    print("error getting position")
    return -1
query = """
SELECT DISTINCT destination
FROM TGVMAX
WHERE NOT axe="AUTOCAR SNCF"
"""

results = run_query(query, as_list=True)
for result in results:
    # print(result)
    print(get_position(result))
# Out:
# ['45.836089' '1.267356']
# ['48.844888' '2.37352']
# ['47.32337' '5.027208']
# ['44.825873' '-0.556697']
# ['45.778945' '3.100543']
# ['46.809737' '1.699536']
# ['47.226497' '2.059822']
# ['48.584967' '7.734584']
# ['43.33633' '3.218873']
# ['45.543884' '3.25398']
# ['46.239792' '1.492151']
# ['45.760559' '4.859355']
# ['43.218029' '2.351824']
# ['45.414246' '3.330167']
# ['49.8153' '6.1333']
# ['44.014387' '1.341496']
# ['45.4407088' '1.5702735']
# ['44.902127' '1.466605']
# ['43.604738' '3.880674']
# ['45.0350122' '3.1062862']
# ['45.152618' '1.528655']
# ['44.208311' '0.620932']
# ['44.066553' '2.983784']
# ['46.561346' '3.338842']
# ['44.7181699' '3.2835489']
# ['47.926801' '1.906629']
# ['44.915888' '-0.236344']
# ['48.869856' '2.78272']
# ['44.7419445' '1.389237']
# ['45.3653797' '3.3106747']
# ['44.1622668' '1.5336541']
# ['43.190387' '3.00591']
# ['48.947773' '6.169838']
# ['47.8415934' '-0.3419359']
# ['43.611206' '1.453616']
# ['49.214806' '3.994632']
# ['44.3247' '3.0571']
# ['47.464647' '-0.55682']
# ['43.9698002' '3.0166261']
# ['44.4477632' '3.1958518']
# ['43.684853' '4.63203']
# ['45.2537695' '3.1965518']
# ['45.889965' '3.120498']
# ['45.571302' '5.919547']
# ['43.832291' '4.365845']
# ['44.013981' '2.9673744']
# ['46.282884' '4.778876']
# ['44.8017375' '3.2706895']
# ['49.859182' '2.8319']
# ['50.636577' '3.06987']
# ['45.721109' '5.074969']
# ['43.105034' '0.729104']
# ['44.4219559' '3.0664008']
# ['43.291762' '-0.369626']
# ['43.8122656' '3.1551583']
# ['48.7856099' '9.1833959']
# ['49.109545' '6.176593']
# ['48.9936164' '8.4020518']
# ['50.901221' '1.810891']
# ['43.412485' '3.69656']
# ['48.103517' '-1.672744']
# ['48.076206' '-0.760907']
# ['44.5089682' '3.252057']
# ['44.991545' '4.978703']
# ['43.484242' '-0.76776']
# ['43.496801' '-1.470306']
# ['50.8356748' '4.3362419']
# ['49.003652' '2.570892']
# ['43.594787' '3.924623']
# ['48.725758' '2.261254']
# ['43.114273' '0.387367']
# ['43.81681' '4.50768']
# ['48.38811' '-4.478903']
# ['46.109425' '5.823483']
# ['43.31728' '3.466203']
# ['50.71683' '3.16804']
# ['47.3781008' '8.5393635']
# ['47.652004' '-2.08777']
# ['41.379793' '2.1402075']
# ['47.68022' '-2.999995']
# ['42.2690' '2.9645']
# ['46.200351' '5.215063']
# ['47.5476225' '7.5896417']
# ['47.755597' '-3.366221']
# ['41.9793006' '2.8199439']
# ['47.247019' '6.022003']
# ['44.449275' '1.433325']
# ['46.15269' '-1.145305']
# ['43.239955' '0.069415']
# ['43.385838' '-1.66122']
# ['46.67212' '-1.435621']
# ['45.4387456' '-0.44164']
# ['43.720472' '-1.050301']
# ['47.216148' '-1.542356']
# ['46.4638232' '-1.1674217']
# ['43.459397' '-1.545915']
# ['43.353132' '-1.781724']
# ['45.74874' '-0.6179']
# ['47.994455' '-4.092103']
# ['46.818594' '0.549279']
# ['46.582275' '0.333241']
# ['47.665169' '-2.75245']
# ['46.669918' '0.377209']
# ['45.191493' '5.714584']
# ['48.7958264' '2.1358827']
# ['43.302666' '5.380407']
# ['47.386099' '0.72355']
# ['43.921586' '4.786079']
# ['46.113238' '-0.762284']
# ['46.948763' '1.985834']
# ['46.319491' '-0.454639']
# ['48.7264211' '2.2575281']
# ['47.821937' '1.021143']
# ['47.096084' '5.488105']
# ['43.6086972' '3.1495688']
# ['50.286673' '2.781942']
# ['44.102344' '3.07457']
# ['43.4675998' '3.2295415']
# ['43.455237' '5.317534']
# ['43.6912097' '3.1689379']
# ['45.653572' '0.164608']
# ['45.901965' '6.121835']
# ['44.503019' '0.168044']
# ['43.12837' '5.929293']
# ['45.947189' '-0.963556']
# ['46.987282' '3.150743']
# ['46.5218269' '6.6327025']
# ['46.976911' '5.799644']
# ['46.7120146' '6.3792318']
# ['49.695024' '4.930373']
# ['49.258978' '4.024435']
# ['43.078109' '0.5735']
# ['49.448764' '1.094087']
# ['47.995689' '0.192578']
# ['49.504393' '4.369566']
# ['48.98984' '1.70337']
# ['49.767915' '4.724952']
# ['49.492996' '0.125677']
# ['48.57797' '-3.832514']
# ['46.126979' '3.430448']
# ['47.585937' '6.897687']
# ['47.307361058531725' '5.953195095062256']
# ['47.742224' '7.342396']
# ['48.978549' '5.270954']
# ['47.389781' '0.693703']
# ['49.4792363' '8.4694107']
# ['46.406607' '-0.201073']
# ['49.4359851' '7.7689299']
# ['48.50758' '-2.765']
# ['44.522951' '2.2718666']
# ['47.286412' '-2.211096']
# ['48.016363' '6.598855']
# ['48.2601166' '7.443278']
# ['46.499917' '-1.78105']
# ['44.5446819' '3.2810718']
# ['42.696292' '2.879779']
# ['48.718142' '4.587581']
# ['48.773308' '5.166822']
# ['45.688161' '5.909371']
# ['43.10037' '-0.042174']
# ['48.453572' '-4.256528']
# ['50.72501' '2.54129']
# ['48.46606' '-2.511546']
# ['50.52144' '2.64055']
# ['48.7610716' '8.239959']
# ['44.559079' '4.744792']
# ['48.122671' '-1.211754']
# ['43.9419' '4.805281']
# ['46.781612' '4.843454']
# ['46.592248' '1.518305']
# ['47.289836' '-2.507442']
# ['46.039383' '4.063207']
# ['46.209185' '3.430614']
# ['44.659009' '-1.16523']
# ['46.302572' '4.824887']
# ['49.353931' '6.169543']
# ['48.073201' '7.346967']
# ['48.689861' '6.174583']
# ['47.023053' '4.848379']
# ['44.137304' '4.819594']
# ['44.928049' '4.893273']
# ['43.29614391' '5.406559']
# ['45.1253044' '2.9791866']
# ['46.765343' '4.499513']
# ['47.618747' '4.33616']
# ['48.54425' '-1.750536']
# ['46.2017559' '6.1466014']
# ['48.646859' '-2.004158']
# ['43.553839' '7.019682']
# ['48.555659' '-3.143343']
# ['43.585784' '7.119498']
# ['43.455524' '6.482498']
# ['49.234362' '6.996379']
# ['48.178005' '6.441787']
# ['47.094145' '2.394255']
# ['45.277542' '6.354716']
# ['45.0219' '64953']
# ['44.9641658' '2.1929167']
# ['47.269' '-0.07136']
# ['43.704556' '7.261904']
# ['46.1842195' '5.5327486']
# ['47.869375' '-3.552693']
# ['50.1066539' '8.6625808']
# ['48.955252' '4.348656']
# ['47.28869' '-2.389102']
# ['47.960273' '-3.832763']
# ['43.42356' '6.769083']
# ['47.2705354' '-2.3445765']
# ['49.1892278' '6.9013184']
# ['45.358411' '9.3238161']
# ['50.371677' '3.089986']
# ['51.03047' '2.368961']
# ['43.580704' '5.000264']
# ['45.443366' '4.399722']
# ['45.0715765' '7.6658551']
# ['50.7157' '1.60964']
# ['50.426818' '2.828254']
# ['46.857596' '6.157767']
# ['48.588233' '6.49727']
# ['48.282225' '6.948656']
# ['48.727638' '-3.460353']
# ['50.41579' '1.64805']
# ['48.4765153' '7.9465414']
# ['48.6062816' '-3.4668231']
# ['48.2459' '7.7816']
# ['44.6746197' '1.8697681']
# ['44.048782' '2.152401']
# ['44.362633' '2.58056']
# ['44.5555678' '2.2182582']
# ['48.3393628' '7.834892950000002']
# ['50.363259' '3.517115']
# ['44.7734284' '1.7223028']
# ['44.464619' '2.4077585']
# ['44.9459316' '1.6663378']
# ['42.54397' '3.022349']
# ['42.7862854' '1.6862985']
# ['42.6594883' '1.8371278']
# ['42.8495385' '1.5999321']
# ['42.969746' '1.607147']
# ['44.921092' '2.435655']
# ['48.73808' '7.05285']
# ['49.4034737' '8.6754223']
# ['44.5782458' '2.0779632']
# ['43.116207' '1.619451']
# ['43.239357' '1.570616']
# ['48.3994159' '9.9826024']
# ['48.7444606' '7.3620802']
# ['50.953481' '1.850819']
# ['50.69561' '3.16348']
# ['44.637384' '-0.96621']
# ['42.539136' '1.8248462']
# ['42.7642849' '1.7531248']
# ['43.348993' '1.468831']
# ['42.4417732' '3.1634033']
# ['44.603515' '2.037355']
# ['44.8183562' '1.6573487']
# ['47.9977308' '7.8412948']
# ['43.108867' '6.124223']
# ['47.2825404' '-2.4331446']
# ['48.1407253' '11.5569426']
# ['42.5899056' '1.8008047']
# ['42.4590464' '1.9045027']
# ['42.7247967' '1.8332516']
# ['48.36559495' '10.886355123140572']
# ['50.51686' '1.64231']
# ['44.5272762' '2.2393128']
# ['46.9314165' '3.0718704']
# ['42.4829582' '3.1250496']
# ['48.841172' '2.320514']
# ['47.369334' '-1.177763']
# ['44.636924' '-1.14295']
# ['42.5971138' '2.9635851']
# ['46.199222' '6.23652']
# ['46.369004' '6.481669']
# ['46.397915' '6.577457']
# ['44.9273692' '1.8436871']
# ['50.6785574' '3.1380315']
# ['42.5136077' '3.1025762']
# error getting position
# -1
# ['42.5269437' '3.0782319']
# ['43.92238' '2.137958']
# ['44.1854793' '2.363504']
# ['44.6746283' '6.6156027']
# ['43.938011' '2.1409629']
# ['44.7301546' '5.0160968']
# ['44.7582549' '5.3632053']
# ['44.889853' '6.633007']
# ['44.6136615' '5.4546227']
# ['44.567008' '6.496773']
# ['44.5458415' '6.2718887']
# ['44.5320046' '5.815764']
# ['44.563693' '6.085638']
# ['45.9819438' '6.9264844']

# %%
# !pip install geopy
from geopy.geocoders import Nominatim

# Initialize geolocator
geolocator = Nominatim(user_agent="geoapi")

# List of city names
locations = [
    "luxembourg",
    "stuttgart hbf",
    "karlsruhe hbf",
    "bruxelles midi brussel zuid",
    "zuerich hb",
    "barcelona sants",
    "figueres vila tgv",
    "basel sbb",
    "girona",
    "lausanne",
    "vallorbe",
    "mannheim hbf",
    "kaiserslautern hbf",
    "baden baden",
    "geneve",
    "sarrebruck/saarbruecken",
    "frankfurt main hbf",
    "milano p garibaldi",
    "torino porta susa",
    "offenbourg/offenburg",
    "ringsheim/eu park",
    "lahr schwarzw",
    "heidelberg hbf",
    "ulm hbf",
    "freiburg breisgau hbf",
    "muenchen hbf",
    "andorre l'hospitalet",
    "augsburg hbf"
]

# Function to get latitude and longitude
def get_lat_lon(place):
    location = geolocator.geocode(place)
    if location:
        return (location.latitude, location.longitude)
    return (None, None)

# Get latitude and longitude for each location
results = []
for place in locations:
    lat, lon = get_lat_lon(place)
    if lat is not None and lon is not None:
        results.append(f"{place};;;{lat};{lon}")

results
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting geopy
#   Downloading geopy-2.4.1-py3-none-any.whl (125 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 125.4/125.4 KB 3.8 MB/s eta 0:00:00
# Collecting geographiclib<3,>=1.52
#   Downloading geographiclib-2.0-py3-none-any.whl (40 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.3/40.3 KB 3.3 MB/s eta 0:00:00
# Installing collected packages: geographiclib, geopy
# Successfully installed geographiclib-2.0 geopy-2.4.1
# ['luxembourg;;;49.6112768;6.129799',
#  'stuttgart hbf;;;48.7856099;9.1833959',
#  'karlsruhe hbf;;;48.9936164;8.4020518',
#  'bruxelles midi brussel zuid;;;50.8356748;4.3362419',
#  'zuerich hb;;;47.3781008;8.5393635',
#  'barcelona sants;;;41.379793;2.1402075',
#  'basel sbb;;;47.5476225;7.5896417',
#  'girona;;;41.9793006;2.8199439',
#  'lausanne;;;46.5218269;6.6327025',
#  'vallorbe;;;46.7120146;6.3792318',
#  'mannheim hbf;;;49.4792363;8.4694107',
#  'kaiserslautern hbf;;;49.4359851;7.7689299',
#  'baden baden;;;48.7610716;8.239959',
#  'geneve;;;46.2017559;6.1466014',
#  'sarrebruck/saarbruecken;;;49.234362;6.996379',
#  'frankfurt main hbf;;;50.1066539;8.6625808',
#  'milano p garibaldi;;;45.358411;9.3238161',
#  'torino porta susa;;;45.0715765;7.6658551',
#  'offenbourg/offenburg;;;48.4765153;7.9465414',
#  'lahr schwarzw;;;48.3393628;7.834892950000002',
#  'heidelberg hbf;;;49.4034737;8.6754223',
#  'ulm hbf;;;48.3994159;9.9826024',
#  'freiburg breisgau hbf;;;47.9977308;7.8412948',
#  'muenchen hbf;;;48.1407253;11.5569426',
#  "andorre l'hospitalet;;;42.5899056;1.8008047",
#  'augsburg hbf;;;48.36559495;10.886355123140572']
